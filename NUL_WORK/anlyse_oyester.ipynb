# %% [markdown]
# #**ANALYSE DES SENTIMENTS DE LA PLATEFORME OYESTER**

# %%
# Importation des modules
import pandas as pd
import numpy as np
import os
import glob
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn as sns

# %% [markdown]
# **IMPORTATIONS DES PATHS DE MES DATASETS**

# %%
# Voir la liste de tous nos fichier
directory = '/content/drive/MyDrive/TALENT VIRTUEL/DATA SCRAPPING/all_datasets'
files = glob.glob(directory + '/*')
files
# Out:
# ['/content/drive/MyDrive/TALENT VIRTUEL/DATA SCRAPPING/all_datasets/deel_capteras.csv',
#  '/content/drive/MyDrive/TALENT VIRTUEL/DATA SCRAPPING/all_datasets/oyster_capteras.csv',
#  '/content/drive/MyDrive/TALENT VIRTUEL/DATA SCRAPPING/all_datasets/remote_capteras.csv',
#  '/content/drive/MyDrive/TALENT VIRTUEL/DATA SCRAPPING/all_datasets/oyster_getapps.csv',
#  '/content/drive/MyDrive/TALENT VIRTUEL/DATA SCRAPPING/all_datasets/deel_truspilot.csv',
#  '/content/drive/MyDrive/TALENT VIRTUEL/DATA SCRAPPING/all_datasets/oysterhr_truspilot.csv',
#  '/content/drive/MyDrive/TALENT VIRTUEL/DATA SCRAPPING/all_datasets/remote_truspilot.csv',
#  '/content/drive/MyDrive/TALENT VIRTUEL/DATA SCRAPPING/all_datasets/rippling_truspilot.csv']

# %% [markdown]
# ## **Data Cleaning et Traitement des données de la plateforme Oyester**

# %%
df1 = pd.read_csv('/content/drive/MyDrive/TALENT VIRTUEL/DATA SCRAPPING/all_datasets/oyster_capteras.csv')
print(df1.shape)
df1.head()
# Out:
# (250, 3)
#   Plateforme                                 Avis Notes sur 5
# 0     Oyster                      Semester review         4,6
# 1     Oyster             Great must have platform         4,6
# 2     Oyster                    Do not use Oyster         4,7
# 3     Oyster  Amazing platform for remote workers         4,7
# 4     Oyster              Good Product, Not Great         4,9

# %%
df1 = df1.drop_duplicates()
df1.shape
# Out:
# (5, 3)

# %%
df2 = pd.read_csv('/content/drive/MyDrive/TALENT VIRTUEL/DATA SCRAPPING/all_datasets/oyster_getapps.csv')
print(df2.shape)
df2.head()
# Out:
# (15, 3)
#   Plateforme                                 Avis Notes sur 5
# 0     Oyster                      Semester review         4,6
# 1     Oyster             Great must have platform         4,6
# 2     Oyster                    Do not use Oyster         4,7
# 3     Oyster  Amazing platform for remote workers         4,7
# 4     Oyster              Good Product, Not Great         4,9

# %%
# Supprimer les colonnes dupliquer
df2 = df2.drop_duplicates()
df2.shape
# Out:
# (5, 3)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Plateforme   5 non-null      object
#  1   Avis         5 non-null      object
#  2   Notes sur 5  5 non-null      object
# dtypes: object(3)
# memory usage: 160.0+ bytes

# %%
 # Remplaçons les virgules par les points
df2['Notes sur 5'] = df2['Notes sur 5'].str.replace(',', '.')
df2['Notes sur 5'] = df2['Notes sur 5'].astype(float)
# Out:
# <ipython-input-8-25b7ec05efde>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Notes sur 5'] = df2['Notes sur 5'].str.replace(',', '.')
# <ipython-input-8-25b7ec05efde>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Notes sur 5'] = df2['Notes sur 5'].astype(float)

# %%
 # Voir la moyenne de la colonne notes
mean_notes = df2['Notes sur 5'].mean()
df2['Notes sur 5'] = df2['Notes sur 5'].fillna(mean_notes)
df2['Notes sur 5'] = df2['Notes sur 5'].astype(int)
# Out:
# <ipython-input-9-344e87816621>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Notes sur 5'] = df2['Notes sur 5'].fillna(mean_notes)
# <ipython-input-9-344e87816621>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Notes sur 5'] = df2['Notes sur 5'].astype(int)

# %%
df3 = pd.read_csv('/content/drive/MyDrive/TALENT VIRTUEL/DATA SCRAPPING/all_datasets/oysterhr_truspilot.csv')
print(df3.shape)
df3.head()
# Out:
# (440, 7)
#    Plateforme             Utilisateur Nombre de commentaires  \
# 0  remote.com  Pieter-Francois Theron               1 review
# 1  remote.com               Cristina               4 reviews
# 2  remote.com         Nimasha Rashani              2 reviews
# 3  remote.com                 Manolis               1 review
# 4  remote.com           Annette Okech               1 review
#
#   Position Géographique                  Date  \
# 0                    ZA            2 days ago
# 1                    ES            2 days ago
# 2                    SE             A day ago
# 3                    GR  Feb 20, 2024Verified
# 4                    KE          Feb 21, 2024
#
#                                                 Avis  Notes sur 5
# 0  By far the easiest and most professional EOR o...            5
# 1  Very good supportJaime was clearly explaining ...            5
# 2  I received on time feedback and action…I recei...            5
# 3  Streamlined serviceSelected to use Remote.com ...            5
# 4  Remote’s customer service is top notchRemote’s...            5

# %%
df3 = df3.drop_duplicates()
df3.shape
# Out:
# (440, 7)

# %%
# Supprimer les colonnes inutiles
df3 = df3.drop(columns = ['Utilisateur', 'Nombre de commentaires', 'Position Géographique', 'Date'], axis= 0)
df3.head()
# Out:
#    Plateforme                                               Avis  Notes sur 5
# 0  remote.com  By far the easiest and most professional EOR o...            5
# 1  remote.com  Very good supportJaime was clearly explaining ...            5
# 2  remote.com  I received on time feedback and action…I recei...            5
# 3  remote.com  Streamlined serviceSelected to use Remote.com ...            5
# 4  remote.com  Remote’s customer service is top notchRemote’s...            5

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 440 entries, 0 to 439
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Plateforme   440 non-null    object
#  1   Avis         440 non-null    object
#  2   Notes sur 5  440 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 13.8+ KB

# %%
# Concaténation
df = pd.concat([df2, df3], ignore_index = True)
print(df.shape)
df.head()
# Out:
# (445, 3)
#   Plateforme                                 Avis  Notes sur 5
# 0     Oyster                      Semester review            4
# 1     Oyster             Great must have platform            4
# 2     Oyster                    Do not use Oyster            4
# 3     Oyster  Amazing platform for remote workers            4
# 4     Oyster              Good Product, Not Great            4

# %%
df['Notes sur 5'].unique()
# Out:
# array([4, 5, 1, 3, 2])

# %%
# Assurez-vous d'avoir importé pandas
import pandas as pd

# Supposez que votre DataFrame est nommé df et qu'il est déjà nettoyé
# Par exemple, vous avez un DataFrame nettoyé comme suit :
# df = ...

# Spécifiez le chemin où vous souhaitez enregistrer le fichier CSV
chemin_du_fichier = "/content/drive/MyDrive/TALENT VIRTUEL/DATA CLEANING/oyester_nettoye.csv"

# Enregistrez le DataFrame dans un fichier CSV
df.to_csv(chemin_du_fichier, index=False)  # Si vous ne voulez pas inclure l'index dans le fichier CSV

# %% [markdown]
# **Simple Analyse des Scores**

# %%
df['Notes sur 5'].value_counts().sort_index().plot(kind='bar', title = "Histogramme des avis",
                                                   xlabel = "Notes sur 5",
                                                   figsize=(10, 5))
# Out:
# <Axes: title={'center': 'Histogramme des avis'}, xlabel='Notes sur 5'>

# %% [markdown]
# **Importation de la bibliothèque NLTK**:

# %%
# Importation des modules
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# **UTILISATION DE VADER POUR LA GESTION DES SCORES DES SENTIMENTS (POSITIVE | NEGATIVE | NEUTRE)**

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

# %%
# Instancier l'analyseur des sentiments
nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
exemple = df['Avis'][50]

# %%
# Voir pour notre exemple les scores des polarités
sia.polarity_scores(exemple)
# Out:
# {'neg': 0.0, 'neu': 0.78, 'pos': 0.22, 'compound': 0.9022}

# %%
df.index
# Out:
# RangeIndex(start=0, stop=445, step=1)

# %%
len(df)
# Out:
# 445

# %%
# Créer une liste de valeurs pour la colonne ID
id_values = ['OYESTER' + str(i) for i in range(1, len(df) + 1)]

# Ajouter la colonne ID au DataFrame
df['ID'] = id_values

# %%
df.head()
# Out:
#   Plateforme                                 Avis  Notes sur 5        ID
# 0     Oyster                      Semester review            4  OYESTER1
# 1     Oyster             Great must have platform            4  OYESTER2
# 2     Oyster                    Do not use Oyster            4  OYESTER3
# 3     Oyster  Amazing platform for remote workers            4  OYESTER4
# 4     Oyster              Good Product, Not Great            4  OYESTER5

# %%
# Passer à l'analyse des scores des polarités pour tout le datasets
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
  text = row['Avis']
  myid = row['ID']
  res[myid] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/445 [00:00<?, ?it/s]

# %%
# Voir le résultats
res
# Out:
# {'OYESTER1': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER2': {'neg': 0.0, 'neu': 0.423, 'pos': 0.577, 'compound': 0.6249},
#  'OYESTER3': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER4': {'neg': 0.0, 'neu': 0.513, 'pos': 0.487, 'compound': 0.5859},
#  'OYESTER5': {'neg': 0.402, 'neu': 0.244, 'pos': 0.354, 'compound': -0.1012},
#  'OYESTER6': {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'compound': 0.8748},
#  'OYESTER7': {'neg': 0.055, 'neu': 0.671, 'pos': 0.274, 'compound': 0.8952},
#  'OYESTER8': {'neg': 0.0, 'neu': 0.845, 'pos': 0.155, 'compound': 0.7841},
#  'OYESTER9': {'neg': 0.053, 'neu': 0.767, 'pos': 0.18, 'compound': 0.6486},
#  'OYESTER10': {'neg': 0.0, 'neu': 0.793, 'pos': 0.207, 'compound': 0.7644},
#  'OYESTER11': {'neg': 0.116, 'neu': 0.825, 'pos': 0.059, 'compound': -0.6604},
#  'OYESTER12': {'neg': 0.0, 'neu': 0.589, 'pos': 0.411, 'compound': 0.971},
#  'OYESTER13': {'neg': 0.0, 'neu': 0.689, 'pos': 0.311, 'compound': 0.9557},
#  'OYESTER14': {'neg': 0.0, 'neu': 0.694, 'pos': 0.306, 'compound': 0.9753},
#  'OYESTER15': {'neg': 0.247, 'neu': 0.715, 'pos': 0.038, 'compound': -0.9791},
#  'OYESTER16': {'neg': 0.0, 'neu': 0.607, 'pos': 0.393, 'compound': 0.9274},
#  'OYESTER17': {'neg': 0.0, 'neu': 0.726, 'pos': 0.274, 'compound': 0.98},
#  'OYESTER18': {'neg': 0.026, 'neu': 0.668, 'pos': 0.306, 'compound': 0.9689},
#  'OYESTER19': {'neg': 0.035, 'neu': 0.663, 'pos': 0.302, 'compound': 0.9447},
#  'OYESTER20': {'neg': 0.015, 'neu': 0.671, 'pos': 0.314, 'compound': 0.9791},
#  'OYESTER21': {'neg': 0.046, 'neu': 0.654, 'pos': 0.3, 'compound': 0.9769},
#  'OYESTER22': {'neg': 0.0, 'neu': 0.684, 'pos': 0.316, 'compound': 0
'neg': 0.0, 'neu': 0.737, 'pos': 0.263, 'compound': 0.802},
#  'OYESTER146': {'neg': 0.143, 'neu': 0.699, 'pos': 0.158, 'compound': 0.128},
#  'OYESTER147': {'neg': 0.081, 'neu': 0.751, 'pos': 0.168, 'compound': 0.4374},
#  'OYESTER148': {'neg': 0.0, 'neu': 0.66, 'pos': 0.34, 'compound': 0.7712},
#  'OYESTER149': {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'compound': 0.4404},
#  'OYESTER150': {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.7902},
#  'OYESTER151': {'neg': 0.0, 'neu': 0.592, 'pos': 0.408, 'compound': 0.8221},
#  'OYESTER152': {'neg': 0.0, 'neu': 0.728, 'pos': 0.272, 'compound': 0.8481},
#  'OYESTER153': {'neg': 0.0, 'neu': 0.647, 'pos': 0.353, 'compound': 0.902},
#  'OYESTER154': {'neg': 0.0, 'neu': 0.831, 'pos': 0.169, 'compound': 0.6908},
#  'OYESTER155': {'neg': 0.0, 'neu': 0.647, 'pos': 0.353, 'compound': 0.872},
#  'OYESTER156': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER157': {'neg': 0.241, 'neu': 0.759, 'pos': 0.0, 'compound': -0.6597},
#  'OYESTER158': {'neg': 0.0, 'neu': 0.561, 'pos': 0.439, 'compound': 0.855},
#  'OYESTER159': {'neg': 0.0, 'neu': 0.683, 'pos': 0.317, 'compound': 0.8516},
#  'OYESTER160': {'neg': 0.0, 'neu': 0.732, 'pos': 0.268, 'compound': 0.6696},
#  'OYESTER161': {'neg': 0.091, 'neu': 0.738, 'pos': 0.171, 'compound': 0.3382},
#  'OYESTER162': {'neg': 0.0, 'neu': 0.719, 'pos': 0.281, 'compound': 0.5994},
#  'OYESTER163': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER164': {'neg': 0.0, 'neu': 0.871, 'pos': 0.129, 'compound': 0.4336},
#  'OYESTER165': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER166': {'neg': 0.127, 'neu': 0.745, 'pos': 0.128, 'compound': 0.255},
#  'OYESTER167': {'neg': 0.0, 'neu': 0.52, 'pos': 0.48, 'compound': 0.8789},
#  'OYESTER168': {'neg': 0.0, 'neu': 0.684, 'pos': 0.316, 'compound': 0.5719},
#  'OYESTER169': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER170': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER171': {'neg': 0.0, 'neu': 0.634, 'pos': 0.366, 'compound': 0.6983},
#  'OYESTER172': {'neg': 0.0, 'neu': 0.485, 'pos': 0.515, 'compound': 0.8588},
#  'OYESTER173': {'neg': 0.0, 'neu': 0.66, 'pos': 0.34, 'compound': 0.7339},
#  'OYESTER174': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER175': {'neg': 0.0, 'neu': 0.652, 'pos': 0.348, 'compound': 0.8427},
#  'OYESTER176': {'neg': 0.0, 'neu': 0.855, 'pos': 0.145, 'compound': 0.5244},
#  'OYESTER177': {'neg': 0.0, 'neu': 0.808, 'pos': 0.192, 'compound': 0.6185},
#  'OYESTER178': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER179': {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.5413},
#  'OYESTER180': {'neg': 0.0, 'neu': 0.594, 'pos': 0.406, 'compound': 0.6249},
#  'OYESTER181': {'neg': 0.0, 'neu': 0.71, 'pos': 0.29, 'compound': 0.5423},
#  'OYESTER182': {'neg': 0.0, 'neu': 0.494, 'pos': 0.506, 'compound': 0.9546},
#  'OYESTER183': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER184': {'neg': 0.0, 'neu': 0.665, 'pos': 0.335, 'compound': 0.5473},
#  'OYESTER185': {'neg': 0.0, 'neu': 0.696, 'pos': 0.304, 'compound': 0.7906},
#  'OYESTER186': {'neg': 0.0, 'neu': 0.391, 'pos': 0.609, 'compound': 0.9325},
#  'OYESTER187': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER188': {'neg': 0.0, 'neu': 0.722, 'pos': 0.278, 'compound': 0.4019},
#  'OYESTER189': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER190': {'neg': 0.128, 'neu': 0.474, 'pos': 0.398, 'compound': 0.6908},
#  'OYESTER191': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER192': {'neg': 0.0, 'neu': 0.721, 'pos': 0.279, 'compound': 0.734},
#  'OYESTER193': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER194': {'neg': 0.0, 'neu': 0.392, 'pos': 0.608, 'compound': 0.8519},
#  'OYESTER195': {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'compound': 0.4389},
#  'OYESTER196': {'neg': 0.0, 'neu': 0.594, 'pos': 0.406, 'compound': 0.6249},
#  'OYESTER197': {'neg': 0.0, 'neu': 0.615, 'pos': 0.385, 'compound': 0.6124},
#  'OYESTER198': {'neg': 0.0, 'neu': 0.721, 'pos': 0.279, 'compound': 0.7003},
#  'OYESTER199': {'neg': 0.0, 'neu': 0.573, 'pos': 0.427, 'compound': 0.7717},
#  'OYESTER200': {'neg': 0.0, 'neu': 0.732, 'pos': 0.268, 'compound': 0.296},
#  'OYESTER201': {'neg': 0.0, 'neu': 0.661, 'pos': 0.339, 'compound': 0.6249},
#  'OYESTER202': {'neg': 0.0, 'neu': 0.861, 'pos': 0.139, 'compound': 0.2732},
#  'OYESTER203': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYEST
'neg': 0.0, 'neu': 0.816, 'pos': 0.184, 'compound': 0.2023},
#  'OYESTER256': {'neg': 0.0, 'neu': 0.861, 'pos': 0.139, 'compound': 0.765},
#  'OYESTER257': {'neg': 0.0, 'neu': 0.844, 'pos': 0.156, 'compound': 0.8176},
#  'OYESTER258': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER259': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER260': {'neg': 0.0, 'neu': 0.541, 'pos': 0.459, 'compound': 0.7783},
#  'OYESTER261': {'neg': 0.204, 'neu': 0.75, 'pos': 0.046, 'compound': -0.9097},
#  'OYESTER262': {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'compound': 0.5106},
#  'OYESTER263': {'neg': 0.037, 'neu': 0.782, 'pos': 0.181, 'compound': 0.8429},
#  'OYESTER264': {'neg': 0.0, 'neu': 0.76, 'pos': 0.24, 'compound': 0.8481},
#  'OYESTER265': {'neg': 0.119, 'neu': 0.774, 'pos': 0.106, 'compound': -0.1531},
#  'OYESTER266': {'neg': 0.0, 'neu': 0.754, 'pos': 0.246, 'compound': 0.5994},
#  'OYESTER267': {'neg': 0.0, 'neu': 0.786, 'pos': 0.214, 'compound': 0.7178},
#  'OYESTER268': {'neg': 0.0, 'neu': 0.622, 'pos': 0.378, 'compound': 0.9325},
#  'OYESTER269': {'neg': 0.0, 'neu': 0.638, 'pos': 0.362, 'compound': 0.8176},
#  'OYESTER270': {'neg': 0.0, 'neu': 0.825, 'pos': 0.175, 'compound': 0.6369},
#  'OYESTER271': {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'compound': 0.6369},
#  'OYESTER272': {'neg': 0.0, 'neu': 0.695, 'pos': 0.305, 'compound': 0.8684},
#  'OYESTER273': {'neg': 0.0, 'neu': 0.74, 'pos': 0.26, 'compound': 0.7959},
#  'OYESTER274': {'neg': 0.0, 'neu': 0.643, 'pos': 0.357, 'compound': 0.9607},
#  'OYESTER275': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER276': {'neg': 0.0, 'neu': 0.758, 'pos': 0.242, 'compound': 0.872},
#  'OYESTER277': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER278': {'neg': 0.098, 'neu': 0.725, 'pos': 0.178, 'compound': 0.296},
#  'OYESTER279': {'neg': 0.0, 'neu': 0.471, 'pos': 0.529, 'compound': 0.8402},
#  'OYESTER280': {'neg': 0.0, 'neu': 0.824, 'pos': 0.176, 'compound': 0.7469},
#  'OYESTER281': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER282': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER283': {'neg': 0.0, 'neu': 0.665, 'pos': 0.335, 'compound': 0.9274},
#  'OYESTER284': {'neg': 0.0, 'neu': 0.732, 'pos': 0.268, 'compound': 0.9523},
#  'OYESTER285': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER286': {'neg': 0.0, 'neu': 0.891, 'pos': 0.109, 'compound': 0.4019},
#  'OYESTER287': {'neg': 0.0, 'neu': 0.547, 'pos': 0.453, 'compound': 0.9744},
#  'OYESTER288': {'neg': 0.0, 'neu': 0.682, 'pos': 0.318, 'compound': 0.6794},
#  'OYESTER289': {'neg': 0.0, 'neu': 0.689, 'pos': 0.311, 'compound': 0.9198},
#  'OYESTER290': {'neg': 0.0, 'neu': 0.758, 'pos': 0.242, 'compound': 0.4939},
#  'OYESTER291': {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'compound': 0.4215},
#  'OYESTER292': {'neg': 0.0, 'neu': 0.812, 'pos': 0.188, 'compound': 0.6996},
#  'OYESTER293': {'neg': 0.0, 'neu': 0.634, 'pos': 0.366, 'compound': 0.8901},
#  'OYESTER294': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER295': {'neg': 0.0, 'neu': 0.56, 'pos': 0.44, 'compound': 0.8807},
#  'OYESTER296': {'neg': 0.0, 'neu': 0.657, 'pos': 0.343, 'compound': 0.7783},
#  'OYESTER297': {'neg': 0.088, 'neu': 0.779, 'pos': 0.133, 'compound': 0.34},
#  'OYESTER298': {'neg': 0.0, 'neu': 0.754, 'pos': 0.246, 'compound': 0.7351},
#  'OYESTER299': {'neg': 0.0, 'neu': 0.588, 'pos': 0.412, 'compound': 0.6808},
#  'OYESTER300': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER301': {'neg': 0.0, 'neu': 0.923, 'pos': 0.077, 'compound': 0.6523},
#  'OYESTER302': {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'compound': 0.7003},
#  'OYESTER303': {'neg': 0.058, 'neu': 0.661, 'pos': 0.281, 'compound': 0.7506},
#  'OYESTER304': {'neg': 0.0, 'neu': 0.615, 'pos': 0.385, 'compound': 0.9621},
#  'OYESTER305': {'neg': 0.0, 'neu': 0.621, 'pos': 0.379, 'compound': 0.8682},
#  'OYESTER306': {'neg': 0.0, 'neu': 0.707, 'pos': 0.293, 'compound': 0.4404},
#  'OYESTER307': {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'compound': 0.3182},
#  'OYESTER308': {'neg': 0.0, 'neu': 0.726, 'pos': 0.274, 'compound': 0.5267},
#  'OYESTER309': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER310': {'neg': 0.0, 'neu': 0.898, 'pos': 0.102, 'compound': 0.2617},
#  'OYESTER311': {'neg': 0.0, 'neu': 0.684, 'pos': 0.316, 'compound': 0.5707},
#  'OYESTER312': {'neg': 0.0, 'neu': 0.613, 'pos': 0.387, 'compound': 0.9001},
#  'OYESTER313': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER314': {'neg': 0.0, 'neu': 0.557, 'pos': 0.443, 'compound': 0.923},
#  'OYESTER315': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER316': {'neg': 0.0, 'neu': 0.586, 'pos': 0.414, 'compound': 0.9246},
#  'OYESTER317': {'neg': 0.0, 'neu': 0.709, 'pos': 0.291, 'compound': 0.5709},
#  'OYESTER318': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER319': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER320': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER321': {'neg': 0.0, 'neu': 0.701, 'pos': 0.299, 'compound': 0.7496},
#  'OYESTER322': {'neg': 0.0, 'neu': 0.568, 'pos': 0.432, 'compound': 0.872},
#  'OYESTER323': {'neg': 0.0, 'neu': 0.585, 'pos': 0.415, 'compound': 0.9348},
#  'OYESTER324': {'neg': 0.0, 'neu': 0.562, 'pos': 0.438, 'compound': 0.9468},
#  'OYESTER325': {'neg': 0.0, 'neu': 0.797, 'pos': 0.203, 'compound': 0.4215},
#  'OYESTER326': {'neg': 0.0, 'neu': 0.645, 'pos': 0.355, 'compound': 0.8779},
#  'OYESTER327': {'neg': 0.084, 'neu': 0.682, 'pos': 0.235, 'compound': 0.5965},
#  'OYESTER328': {'neg': 0.0, 'neu': 0.802, 'pos': 0.198, 'compound': 0.734},
#  'OYESTER329': {'neg': 0.0, 'neu': 0.766, 'pos': 0.234, 'compound': 0.6705},
#  'OYESTER330': {'neg': 0.0, 'neu': 0.88, 'pos': 0.12, 'compound': 0.2942},
#  'OYESTER331': {'neg': 0.0, 'neu': 0.544, 'pos': 0.456, 'compound': 0.9729},
#  'OYESTER332': {'neg': 0.016, 'neu': 0.832, 'pos': 0.153, 'compound': 0.9634},
#  'OYESTER333': {'neg': 0.0, 'neu': 0.619, 'pos': 0.381, 'compound': 0.9392},
#  'OYESTER334': {'neg': 0.0, 'neu': 0.561, 'pos': 0.439, 'compound': 0.8225},
#  'OYESTER335': {'neg': 0.0, 'neu': 0.795, 'pos': 0.205, 'compound': 0.7713},
#  'OYESTER336': {'neg': 0.0, 'neu': 0.813, 'pos': 0.187, 'compound': 0.7783},
#  'OYESTER337': {'neg': 0.066, 'neu': 0.848, 'pos': 0.086, 'compound': 0.6051},
#  'OYESTER338': {'neg': 0.0, 'neu': 0.839, 'pos': 0.161, 'compound': 0.8735},
#  'OYESTER339': {'neg': 0.0, 'neu': 0.631, 'pos': 0.369, 'compound': 0.6249},
#  'OYESTER340': {'neg': 0.0, 'neu': 0.528, 'pos': 0.472, 'compound': 0.9231},
#  'OYESTER341': {'neg': 0.0, 'neu': 0.68, 'pos': 0.32, 'compound': 0.9664},
#  'OYESTER342': {'neg': 0.0, 'neu': 0.621, 'pos': 0.379, 'compound': 0.9523},
#  'OYESTER343': {'neg': 0.0, 'neu': 0.66, 'pos': 0.34, 'compound': 0.9729},
#  'OYESTER344': {'neg': 0.0, 'neu': 0.602, 'pos': 0.398, 'compound': 0.9503},
#  'OYESTER345': {'neg': 0.0, 'neu': 0.929, 'pos': 0.071, 'compound': 0.2263},
#  'OYESTER346': {'neg': 0.116, 'neu': 0.734, 'pos': 0.15, 'compound': 0.9313},
#  'OYESTER347': {'neg': 0.0, 'neu': 0.915, 'pos': 0.085, 'compound': 0.4019},
#  'OYESTER348': {'neg': 0.0, 'neu': 0.673, 'pos': 0.327, 'compound': 0.7783},
#  'OYESTER349': {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.4215},
#  'OYESTER350': {'neg': 0.0, 'neu': 0.815, 'pos': 0.185, 'compound': 0.7654},
#  'OYESTER351': {'neg': 0.031, 'neu': 0.807, 'pos': 0.162, 'compound': 0.8507},
#  'OYESTER352': {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.4926},
#  'OYESTER353': {'neg': 0.0, 'neu': 0.823, 'pos': 0.177, 'compound': 0.4215},
#  'OYESTER354': {'neg': 0.0, 'neu': 0.816, 'pos': 0.184, 'compound': 0.2023},
#  'OYESTER355': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER356': {'neg': 0.0, 'neu': 0.512, 'pos': 0.488, 'compound': 0.9588},
#  'OYESTER357': {'neg': 0.0, 'neu': 0.79, 'pos': 0.21, 'compound': 0.4926},
#  'OYESTER358': {'neg': 0.0, 'neu': 0.858, 'pos': 0.142, 'compound': 0.8936},
#  'OYESTER359': {'neg': 0.045, 'neu': 0.719, 'pos': 0.236, 'compound': 0.962},
#  'OYESTER360': {'neg': 0.0, 'neu': 0.706, 'pos': 0.294, 'compound': 0.7959},
#  'OYESTER361': {'neg': 0.01, 'neu': 0.756, 'pos': 0.233, 'compound': 0.9804},
#  'OYESTER362': {'neg': 0.0, 'neu': 0.803, 'pos': 0.197, 'compound': 0
{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER410': {'neg': 0.0, 'neu': 0.582, 'pos': 0.418, 'compound': 0.9607},
#  'OYESTER411': {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'compound': 0.9042},
#  'OYESTER412': {'neg': 0.05, 'neu': 0.64, 'pos': 0.31, 'compound': 0.9598},
#  'OYESTER413': {'neg': 0.0, 'neu': 0.652, 'pos': 0.348, 'compound': 0.8803},
#  'OYESTER414': {'neg': 0.093, 'neu': 0.832, 'pos': 0.075, 'compound': -0.3054},
#  'OYESTER415': {'neg': 0.041, 'neu': 0.793, 'pos': 0.166, 'compound': 0.6542},
#  'OYESTER416': {'neg': 0.0, 'neu': 0.755, 'pos': 0.245, 'compound': 0.8307},
#  'OYESTER417': {'neg': 0.119, 'neu': 0.823, 'pos': 0.059, 'compound': -0.4215},
#  'OYESTER418': {'neg': 0.0, 'neu': 0.675, 'pos': 0.325, 'compound': 0.8481},
#  'OYESTER419': {'neg': 0.022, 'neu': 0.953, 'pos': 0.025, 'compound': 0.0772},
#  'OYESTER420': {'neg': 0.074, 'neu': 0.7, 'pos': 0.226, 'compound': 0.5007},
#  'OYESTER421': {'neg': 0.059, 'neu': 0.724, 'pos': 0.217, 'compound': 0.879},
#  'OYESTER422': {'neg': 0.0, 'neu': 0.672, 'pos': 0.328, 'compound': 0.9439},
#  'OYESTER423': {'neg': 0.0, 'neu': 0.705, 'pos': 0.295, 'compound': 0.7717},
#  'OYESTER424': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER425': {'neg': 0.014, 'neu': 0.814, 'pos': 0.172, 'compound': 0.9967},
#  'OYESTER426': {'neg': 0.0, 'neu': 0.772, 'pos': 0.228, 'compound': 0.7783},
#  'OYESTER427': {'neg': 0.0, 'neu': 0.813, 'pos': 0.187, 'compound': 0.9541},
#  'OYESTER428': {'neg': 0.0, 'neu': 0.699, 'pos': 0.301, 'compound': 0.9335},
#  'OYESTER429': {'neg': 0.0, 'neu': 0.674, 'pos': 0.326, 'compound': 0.4404},
#  'OYESTER430': {'neg': 0.044, 'neu': 0.747, 'pos': 0.21, 'compound': 0.957},
#  'OYESTER431': {'neg': 0.0, 'neu': 0.708, 'pos': 0.292, 'compound': 0.7351},
#  'OYESTER432': {'neg': 0.177, 'neu': 0.713, 'pos': 0.111, 'compound': -0.4019},
#  'OYESTER433': {'neg': 0.055, 'neu': 0.897, 'pos': 0.048, 'compound': -0.0129},
#  'OYESTER434': {'neg': 0.0, 'neu': 0.574, 'pos': 0.426, 'compound': 0.6369},
#  'OYESTER435': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'OYESTER436': {'neg': 0.102, 'neu': 0.71, 'pos': 0.188, 'compound': 0.6745},
#  'OYESTER437': {'neg': 0.0, 'neu': 0.752, 'pos': 0.248, 'compound': 0.836},
#  'OYESTER438': {'neg': 0.092, 'neu': 0.82, 'pos': 0.088, 'compound': -0.0138},
#  'OYESTER439': {'neg': 0.0, 'neu': 0.634, 'pos': 0.366, 'compound': 0.9432},
#  'OYESTER440': {'neg': 0.0, 'neu': 0.633, 'pos': 0.367, 'compound': 0.7003},
#  'OYESTER441': {'neg': 0.0, 'neu': 0.671, 'pos': 0.329, 'compound': 0.6588},
#  'OYESTER442': {'neg': 0.0, 'neu': 0.483, 'pos': 0.517, 'compound': 0.9738},
#  'OYESTER443': {'neg': 0.0, 'neu': 0.811, 'pos': 0.189, 'compound': 0.9071},
#  'OYESTER444': {'neg': 0.026, 'neu': 0.685, 'pos': 0.29, 'compound': 0.9856},
#  'OYESTER445': {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'compound': 0.4019}}

# %%
# Transformer ça en dataframe pour bien le manipuler
df_vader = pd.DataFrame(res).T
df_vader = df_vader.reset_index().rename(columns={'index':'ID'})
df_vader = df_vader.merge(df, how='left')

# %%
df_vader.head()
# Out:
#          ID    neg    neu    pos  compound Plateforme  \
# 0  OYESTER1  0.000  1.000  0.000    0.0000     Oyster
# 1  OYESTER2  0.000  0.423  0.577    0.6249     Oyster
# 2  OYESTER3  0.000  1.000  0.000    0.0000     Oyster
# 3  OYESTER4  0.000  0.513  0.487    0.5859     Oyster
# 4  OYESTER5  0.402  0.244  0.354   -0.1012     Oyster
#
#                                   Avis  Notes sur 5
# 0                      Semester review            4
# 1             Great must have platform            4
# 2                    Do not use Oyster            4
# 3  Amazing platform for remote workers            4
# 4              Good Product, Not Great            4

# %% [markdown]
# **Affichage des graphiques du Vaders**

# %%
ax = sns.barplot(data = df_vader, x = 'Notes sur 5', y = 'compound')
ax.set_title("Résultats du vader vs notes sur 5")
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
sns.barplot(data = df_vader, x ='Notes sur 5', y = 'pos',  ax = axs[0])
sns.barplot(data = df_vader, x = 'Notes sur 5', y = 'neu', ax = axs[1])
sns.barplot(data = df_vader, x = 'Notes sur 5', y = 'neg', ax = axs[2])
axs[0].set_title('Positive')
axs[1].set_title('Neutral')
axs[2].set_title('Negative')
plt.show()

# %% [markdown]
# #Pré-entrainement du modèle

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
# Utilisation d'un modèle pré-entrainé
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()

# %%
# Voir le score des textes  avec notre VADER
print(exemple)

sia.polarity_scores(text)
# Out:
# Great Experience, with one-to-one help from onboarding specialistShuchi, my onboarding specialist was always available for help while I was registering for my new role through remote.  Her responsiveness and knowledge helped me resolve any query I had quickly and sped up my onboarding process.Date of experience: July 20, 2023
# {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'compound': 0.4019}

# %%
print(exemple)
# Out:
# Great Experience, with one-to-one help from onboarding specialistShuchi, my onboarding specialist was always available for help while I was registering for my new role through remote.  Her responsiveness and knowledge helped me resolve any query I had quickly and sped up my onboarding process.Date of experience: July 20, 2023

# %%
# Exécuter notre modèle de NLP basé sur Roberta Model
encoded_text = tokenizer(exemple, return_tensors='pt')
output = model(**encoded_text)
scores = output[0][0].detach().numpy()
scores = softmax(scores)
scores_dict = {
    'roberta_neg': scores[0],
    'roberta_neu': scores[1],
    'roberta_pos': scores[2]
}
scores_dict
# Out:
# {'roberta_neg': 0.0016235864,
#  'roberta_neu': 0.021740366,
#  'roberta_pos': 0.976636}

# %%
# Utilisationn du modèle sur notre datasests
def polarity_scores_roberta(exemple):
    encoded_text = tokenizer(exemple, return_tensors='pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict = {
        'roberta_neg': scores[0],
        'roberta_neu': scores[1],
        'roberta_pos': scores[2]
    }
    return scores_dict

# %%
# Passer à l'analyse des scores des polarités pour tout le datasets
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
 try:
      text = row['Avis']
      myid = row['ID']
      vader_result = sia.polarity_scores(text)
      vader_result_rename = {}
      for key, value in vader_result.items():
        vader_result_rename[f"vader_{key}"] = value
      robertar_result = polarity_scores_roberta(text)

      robertar_result = polarity_scores_roberta(text)
      both = {**vader_result, **robertar_result}
      res[myid] = both
 except RuntimeError:
      print(f'Stoppé pour le numéro {myid}')
# Out:
#   0%|          | 0/445 [00:00<?, ?it/s]
# Stoppé pour le numéro OYESTER166
# Stoppé pour le numéro OYESTER425

# %%
results_df = pd.DataFrame(res).T
results_df = results_df.reset_index().rename(columns={'index':'ID'})
results_df = results_df.merge(df, how='left')

# %%
results_df
# Out:
#              ID    neg    neu    pos  compound  roberta_neg  roberta_neu  \
# 0      OYESTER1  0.000  1.000  0.000    0.0000     0.163883     0.753832
# 1      OYESTER2  0.000  0.423  0.577    0.6249     0.005115     0.094437
# 2      OYESTER3  0.000  1.000  0.000    0.0000     0.727042     0.258605
# 3      OYESTER4  0.000  0.513  0.487    0.5859     0.003153     0.058337
# 4      OYESTER5  0.402  0.244  0.354   -0.1012     0.415264     0.428120
# ..          ...    ...    ...    ...       ...          ...          ...
# 438  OYESTER441  0.000  0.671  0.329    0.6588     0.003690     0.144936
# 439  OYESTER442  0.000  0.483  0.517    0.9738     0.001530     0.011076
# 440  OYESTER443  0.000  0.811  0.189    0.9071     0.001718     0.009824
# 441  OYESTER444  0.026  0.685  0.290    0.9856     0.001837     0.010369
# 442  OYESTER445  0.000  0.876  0.124    0.4019     0.001364     0.029086
#
#      roberta_pos  Plateforme  \
# 0       0.082285      Oyster
# 1       0.900448      Oyster
# 2       0.014353      Oyster
# 3       0.938510      Oyster
# 4       0.156616      Oyster
# ..           ...         ...
# 438     0.851373  remote.com
# 439     0.987393  remote.com
# 440     0.988457  remote.com
# 441     0.987794  remote.com
# 442     0.969551  remote.com
#
#                                                   Avis  Notes sur 5
# 0                                      Semester review            4
# 1                             Great must have platform            4
# 2                                    Do not use Oyster            4
# 3                  Amazing platform for remote workers            4
# 4                              Good Product, Not Great            4
# ..                                                 ...          ...
# 438  PayslipSuper responsive and clear answer about...            5
# 439  Great user support from OluwakemiHello! Oluwak...            5
# 440  I'm using Remote since a couple of…I'm using R...            5
# 441  Remote & Maruthi MedisettyRemote's offering an...            5
# 442  Onboarding experience in IrelandThanks a lot f...            5
#
# [443 rows x 11 columns]

# %% [markdown]
# ###**Comparer les deux modèles**

# %%
results_df.columns
# Out:
# Index(['ID', 'neg', 'neu', 'pos', 'compound', 'roberta_neg', 'roberta_neu',
#        'roberta_pos', 'Plateforme', 'Avis', 'Notes sur 5'],
#       dtype='object')

# %%
sns.pairplot(data = results_df, vars = ['neg', 'neu', 'pos', 'compound',
                                       'roberta_neg', 'roberta_neu',
                                       'roberta_pos'],
             hue='Notes sur 5',
             palette = 'tab10')
plt.show()

# %%
# Tester notre modèles sur nos données
results_df.head()
# Out:
#          ID    neg    neu    pos  compound  roberta_neg  roberta_neu  \
# 0  OYESTER1  0.000  1.000  0.000    0.0000     0.163883     0.753832
# 1  OYESTER2  0.000  0.423  0.577    0.6249     0.005115     0.094437
# 2  OYESTER3  0.000  1.000  0.000    0.0000     0.727042     0.258605
# 3  OYESTER4  0.000  0.513  0.487    0.5859     0.003153     0.058337
# 4  OYESTER5  0.402  0.244  0.354   -0.1012     0.415264     0.428120
#
#    roberta_pos Plateforme                                 Avis  Notes sur 5
# 0     0.082285     Oyster                      Semester review            4
# 1     0.900448     Oyster             Great must have platform            4
# 2     0.014353     Oyster                    Do not use Oyster            4
# 3     0.938510     Oyster  Amazing platform for remote workers            4
# 4     0.156616     Oyster              Good Product, Not Great            4

# %%
# Renommons la dernière colonne
results_df = results_df.rename(columns={'Notes sur 5' : 'Scores'})
results_df.head()
# Out:
#          ID    neg    neu    pos  compound  roberta_neg  roberta_neu  \
# 0  OYESTER1  0.000  1.000  0.000    0.0000     0.163883     0.753832
# 1  OYESTER2  0.000  0.423  0.577    0.6249     0.005115     0.094437
# 2  OYESTER3  0.000  1.000  0.000    0.0000     0.727042     0.258605
# 3  OYESTER4  0.000  0.513  0.487    0.5859     0.003153     0.058337
# 4  OYESTER5  0.402  0.244  0.354   -0.1012     0.415264     0.428120
#
#    roberta_pos Plateforme                                 Avis  Scores
# 0     0.082285     Oyster                      Semester review       4
# 1     0.900448     Oyster             Great must have platform       4
# 2     0.014353     Oyster                    Do not use Oyster       4
# 3     0.938510     Oyster  Amazing platform for remote workers       4
# 4     0.156616     Oyster              Good Product, Not Great       4

# %%
# Vérification de la reponses avec Robertar
results_df.query('Scores == 1').sort_values('roberta_pos', ascending = False)['Avis'].values[3]
# Out:
# 'Absolutely appaling serviceAbsolutely appaling service - 70 emails back and forth and keep being passed around to different people who clearly do not even read the thread. Avoid like the plague .......Date of experience: July 21, 2023'

# %%
# Vérification de la reponses avec Vader
results_df.query('Scores == 1').sort_values('pos', ascending = False)['Avis'].values[3]
# Out:
# 'Terrible onboarding and customer…Terrible onboarding and customer support, and then on top of all that, delayed salary payments. This company has no idea how to run a business. Stay away.Date of experience: November 30, 2022'

# %%
results_df.query('Scores == 5').sort_values('roberta_pos', ascending = False)['Avis'].values[1]
# Out:
# "Amazing Customer ServiceRemote.com is the best! Very easy to use and navigate! The best part is the customer service! They're super responsive and helpful!Date of experience: August 08, 2023"

# %%
results_df.query('Scores == 5').sort_values('pos', ascending = False)['Avis'].values[123]
# Out:
# 'Great support experienceGreat support experience, I felt guided and accompanied for the whole process of my request, which was rather complex. Thank you so much JaimeDate of experience: December 29, 2023'

# %%
results_df.columns
# Out:
# Index(['ID', 'neg', 'neu', 'pos', 'compound', 'roberta_neg', 'roberta_neu',
#        'roberta_pos', 'Plateforme', 'Avis', 'Scores'],
#       dtype='object')

# %% [markdown]
# **METTRE AU CLAIR LE DATASETS**

# %%
df = results_df.drop(columns = ['neg', 'neu', 'pos', 'compound'], axis = 1)
df.head()
# Out:
#          ID  roberta_neg  roberta_neu  roberta_pos Plateforme  \
# 0  OYESTER1     0.163883     0.753832     0.082285     Oyster
# 1  OYESTER2     0.005115     0.094437     0.900448     Oyster
# 2  OYESTER3     0.727042     0.258605     0.014353     Oyster
# 3  OYESTER4     0.003153     0.058337     0.938510     Oyster
# 4  OYESTER5     0.415264     0.428120     0.156616     Oyster
#
#                                   Avis  Scores
# 0                      Semester review       4
# 1             Great must have platform       4
# 2                    Do not use Oyster       4
# 3  Amazing platform for remote workers       4
# 4              Good Product, Not Great       4

# %% [markdown]
# # **Utilisation des Transformers pour être plus précis**

# %%
from transformers import pipeline
sent_pipeline = pipeline('sentiment-analysis')
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
# Exemple du mode de fonctionnement des transformers
sent_pipeline("I love m'y self")
# Out:
# [{'label': 'POSITIVE', 'score': 0.9997005462646484}]

# %%
# Applications sur l'ensembles de nos datasets
def analyze_sentiment(text):
  return sent_pipeline(text)[0]

# Créer une dernière colonne
df['Sentiment'] = df['Avis'].apply(analyze_sentiment)

# %%
df.head()
# Out:
#          ID  roberta_neg  roberta_neu  roberta_pos Plateforme  \
# 0  OYESTER1     0.163883     0.753832     0.082285     Oyster
# 1  OYESTER2     0.005115     0.094437     0.900448     Oyster
# 2  OYESTER3     0.727042     0.258605     0.014353     Oyster
# 3  OYESTER4     0.003153     0.058337     0.938510     Oyster
# 4  OYESTER5     0.415264     0.428120     0.156616     Oyster
#
#                                   Avis  Scores  \
# 0                      Semester review       4
# 1             Great must have platform       4
# 2                    Do not use Oyster       4
# 3  Amazing platform for remote workers       4
# 4              Good Product, Not Great       4
#
#                                            Sentiment
# 0  {'label': 'POSITIVE', 'score': 0.9758715033531...
# 1  {'label': 'POSITIVE', 'score': 0.9978218078613...
# 2  {'label': 'NEGATIVE', 'score': 0.9390276074409...
# 3  {'label': 'POSITIVE', 'score': 0.9998052716255...
# 4  {'label': 'NEGATIVE', 'score': 0.6335225701332...

# %%
# Créer de nouvelles colonnes pour être plus précis et fuide
## Extraire les classes
df['Classe'] = df['Sentiment'].apply(lambda x: x['label'])
## Vérification des classes
print(df['Classe'].unique())
## Extraires les proportions affectés à chaque classes
df['Proportion_classe'] = df['Sentiment'].apply(lambda x: x['score'])
## Vérification des proportions
print(df['Proportion_classe'].unique())
# Out:
# ['POSITIVE' 'NEGATIVE']
# [0.9758715  0.99782181 0.93902761 0.99980527 0.63352257 0.99817419
#  0.99970335 0.9994505  0.99812049 0.99978751 0.99982327 0.99985421
#  0.99936229 0.99979168 0.99977428 0.98927033 0.99068975 0.99981052
#  0.99927419 0.99975032 0.99636322 0.99864048 0.99945635 0.99940276
#  0.99984789 0.99882561 0.99980301 0.99983966 0.99029374 0.99944252
#  0.99981409 0.9993456  0.99970078 0.99899536 0.95949233 0.99909639
#  0.88731831 0.99968386 0.98365331 0.999331   0.99972528 0.98736423
#  0.9790917  0.9985109  0.9986105  0.99982834 0.99981076 0.99798679
#  0.99951005 0.99976414 0.99953616 0.99973792 0.99980587 0.99960941
#  0.99948019 0.99969184 0.97953403 0.99922323 0.99817765 0.54633474
#  0.99927336 0.99963486 0.99627316 0.99982435 0.99986076 0.99973553
#  0.99971622 0.99825257 0.99866426 0.9918167  0.99981648 0.99888772
#  0.9997009  0.93553561 0.9996562  0.99972087 0.99979955 0.99977905
#  0.99971849 0.99981278 0.99954444 0.99537742 0.99923861 0.99979657
#  0.99986553 0.9996419  0.99958378 0.99963856 0.9998042  0.99947709
#  0.99846798 0.99880254 0.99961436 0.99947602 0.99931455 0.99725085
#  0.99456561 0.99983239 0.99933147 0.99823427 0.99911028 0.9996165
#  0.9994061  0.99948668 0.99195707 0.99939668 0.77122813 0.99978799
#  0.99980813 0.99967682 0.9997918  0.99030101 0.9993605  0.99987364
#  0.99983525 0.99939823 0.99506539 0.99985826 0.99951088 0.99292314
#  0.99985743 0.99912399 0.99936169 0.99873394 0.963476   0.99965727
#  0.99895835 0.99289578 0.99968779 0.9995296  0.9998678  0.98653698
#  0.99949384 0.99847311 0.9942674  0.99620241 0.99975425 0.99741262
#  0.99565816 0.99984229 0.99927181 0.99335504 0.98121774 0.98910248
#  0.99957627 0.9997142  0.99980122 0.99978846 0.60733831 0.99835241
#  0.99881953 0.99821657 0.9973889  0.99932945 0.99984479 0.99980778
#  0.99942017 0.99622619 0.9994604  0.99735653 0.99982387 0.99845803
#  0.99838984 0.99948442 0.99936396 0.99964345 0.99941504 0.996387
#  0.99985564 0.99965537 0.84402537 0.99498028 0.99962473 0.99870729
#  0.99824846 0.99038029 0.99890339 0.99980074 0.9996137  0.99603146
#  0.99356961 0.97478569 0.99969089 0.99934846 0.99813372 0.99975985
#  0.99979931 0.97483307]

# %%
# Voir notre nouvelle dataframe
df.head()
# Out:
#          ID  roberta_neg  roberta_neu  roberta_pos Plateforme  \
# 0  OYESTER1     0.163883     0.753832     0.082285     Oyster
# 1  OYESTER2     0.005115     0.094437     0.900448     Oyster
# 2  OYESTER3     0.727042     0.258605     0.014353     Oyster
# 3  OYESTER4     0.003153     0.058337     0.938510     Oyster
# 4  OYESTER5     0.415264     0.428120     0.156616     Oyster
#
#                                   Avis  Scores  \
# 0                      Semester review       4
# 1             Great must have platform       4
# 2                    Do not use Oyster       4
# 3  Amazing platform for remote workers       4
# 4              Good Product, Not Great       4
#
#                                            Sentiment    Classe  \
# 0  {'label': 'POSITIVE', 'score': 0.9758715033531...  POSITIVE
# 1  {'label': 'POSITIVE', 'score': 0.9978218078613...  POSITIVE
# 2  {'label': 'NEGATIVE', 'score': 0.9390276074409...  NEGATIVE
# 3  {'label': 'POSITIVE', 'score': 0.9998052716255...  POSITIVE
# 4  {'label': 'NEGATIVE', 'score': 0.6335225701332...  NEGATIVE
#
#    Proportion_classe
# 0           0.975872
# 1           0.997822
# 2           0.939028
# 3           0.999805
# 4           0.633523

# %%
# Supprimer la colonne du modèle roberta qui est déjà utilisé par notre transformer
df = df.drop(columns = ['roberta_neg', 'roberta_pos', 'roberta_neu', 'Sentiment'], axis=1)
df.head()
# Out:
#          ID Plateforme                                 Avis  Scores    Classe  \
# 0  OYESTER1     Oyster                      Semester review       4  POSITIVE
# 1  OYESTER2     Oyster             Great must have platform       4  POSITIVE
# 2  OYESTER3     Oyster                    Do not use Oyster       4  NEGATIVE
# 3  OYESTER4     Oyster  Amazing platform for remote workers       4  POSITIVE
# 4  OYESTER5     Oyster              Good Product, Not Great       4  NEGATIVE
#
#    Proportion_classe
# 0           0.975872
# 1           0.997822
# 2           0.939028
# 3           0.999805
# 4           0.633523

# %% [markdown]
# # **Analyse des Tendances**

# %%
df.head()
# Out:
#          ID Plateforme                                 Avis  Scores    Classe  \
# 0  OYESTER1     Oyster                      Semester review       4  POSITIVE
# 1  OYESTER2     Oyster             Great must have platform       4  POSITIVE
# 2  OYESTER3     Oyster                    Do not use Oyster       4  NEGATIVE
# 3  OYESTER4     Oyster  Amazing platform for remote workers       4  POSITIVE
# 4  OYESTER5     Oyster              Good Product, Not Great       4  NEGATIVE
#
#    Proportion_classe
# 0           0.975872
# 1           0.997822
# 2           0.939028
# 3           0.999805
# 4           0.633523

# %% [markdown]
# **HISTOGRAMME DE LA DISTRIBUTION DE LA CLASSE DES SENTIMENTS DE LA PLATEFORME OYESTER**

# %%
df['Classe'].value_counts().plot(kind = 'bar', title = "Histogramme de la classe des avis",
                                 xlabel = 'Classe',
                                 figsize = (10, 5))
plt.show()

# %% [markdown]
# **Voir la distribution entre la prédiction des classes de notre transformers et puis le score réel affectés par l'internautes**

# %%
# Grouper d'abord les deux colonnes cibles
df.groupby('Classe')['Scores'].value_counts().unstack().plot(kind = 'bar',
                                                             title = "Relation entre Classe et Scores",
                                                             xlabel = "Classe",
                                                             ylabel = "Proportion des scores suivant la classe")
# Out:
# <Axes: title={'center': 'Relation entre Classe et Scores'}, xlabel='Classe', ylabel='Proportion des scores suivant la classe'>

# %%
df.head()
# Out:
#          ID Plateforme                                 Avis  Scores    Classe  \
# 0  OYESTER1     Oyster                      Semester review       4  POSITIVE
# 1  OYESTER2     Oyster             Great must have platform       4  POSITIVE
# 2  OYESTER3     Oyster                    Do not use Oyster       4  NEGATIVE
# 3  OYESTER4     Oyster  Amazing platform for remote workers       4  POSITIVE
# 4  OYESTER5     Oyster              Good Product, Not Great       4  NEGATIVE
#
#    Proportion_classe
# 0           0.975872
# 1           0.997822
# 2           0.939028
# 3           0.999805
# 4           0.633523

# %% [markdown]
# **IDENTIFICATION DES POINTS FORTS ET DES FAIBLESSES DE LA PLATEFORME OYESTER SELON LES AVIS DES CLIENTS**

# %%
df.head()
# Out:
#          ID Plateforme                                 Avis  Scores    Classe  \
# 0  OYESTER1     Oyster                      Semester review       4  POSITIVE
# 1  OYESTER2     Oyster             Great must have platform       4  POSITIVE
# 2  OYESTER3     Oyster                    Do not use Oyster       4  NEGATIVE
# 3  OYESTER4     Oyster  Amazing platform for remote workers       4  POSITIVE
# 4  OYESTER5     Oyster              Good Product, Not Great       4  NEGATIVE
#
#    Proportion_classe
# 0           0.975872
# 1           0.997822
# 2           0.939028
# 3           0.999805
# 4           0.633523

# %%
#Créer de nouvelles jeux de données
reviews_positive = df[df['Classe'] == "POSITIVE"] # Avis positive
reviews_negative = df[df['Classe'] == "NEGATIVE"] # Avis negative

# %%
# Trier
trie_reviews_positive = reviews_positive.sort_values(by = "Proportion_classe", ascending = False)
trie_reviews_negative = reviews_negative.sort_values(by = "Proportion_classe", ascending = False)

# %%
# Les avis positifs
sorted_reviews_positive = trie_reviews_positive['Avis']

# Créer un DataFrame avec les avis triés
sorted_reviews_positive_df = pd.DataFrame(sorted_reviews_positive, columns=['Avis'])

# %%
# Les avis negative
sorted_reviews_negative = trie_reviews_negative['Avis']

# Créer un DataFrame avec les avis triés
sorted_reviews_negative_df = pd.DataFrame(sorted_reviews_negative, columns=['Avis'])

# %%
# Réinitialiser les index
sorted_reviews_positive_df.reset_index(drop=True, inplace=True)
sorted_reviews_positive_df.head()
# Out:
#                                                 Avis
# 0  Emy has truly enhanced my experience…Emy has t...
# 1  Shuchi was amazingShuchi was amazing! Clear, c...
# 2  Adriana is the best!!Adriana Cespedes was grea...
# 3  Very good!Very good!I have good experience wit...
# 4  Great service and great support!Date of experi...

# %%
# Réinitialiser les index
sorted_reviews_negative_df.reset_index(drop=True, inplace=True)
sorted_reviews_negative_df.head()
# Out:
#                                                 Avis
# 0  Worst customer service in the world.I've been ...
# 1  This company does not have a clue on…This comp...
# 2  Terrible onboarding and customer…Terrible onbo...
# 3  Very bad serviceVery bad service. It takes wee...
# 4  This company's incompetence is beyond…This com...

# %%
# Afficher le premier avis positifs
exemple = sorted_reviews_positive_df['Avis'][0]
exemple
# Out:
# 'Emy has truly enhanced my experience…Emy has truly enhanced my experience and made it exceptionally positive. I am grateful for her remarkable ability to provide me with the necessary information promptly, along with her swift responses.Date of experience: June 14, 2023'

# %%
# Afficher le premier avis negatif
exemple2 = sorted_reviews_negative_df['Avis'][0]
exemple2
# Out:
# "Worst customer service in the world.I've been asking for form T220  for a month and nobody wants to help me. Customer service is not responsive. No way to contact them. It is responsibility of remote.com to provide their employees with form T220 for tax filing. They won't even provide it . They keep on saying technical glitch for more than a month now. Avoid this company please!!Date of experience: February 18, 2024"

# %%
# Voyons les 20 premiers commentaires positifs
nmbre_commentaires = 20

for i in range(nmbre_commentaires):
  print(sorted_reviews_positive_df['Avis'][i])
# Out:
# Emy has truly enhanced my experience…Emy has truly enhanced my experience and made it exceptionally positive. I am grateful for her remarkable ability to provide me with the necessary information promptly, along with her swift responses.Date of experience: June 14, 2023
# Shuchi was amazingShuchi was amazing! Clear, concise and very responsive.Date of experience: August 17, 2023
# Adriana is the best!!Adriana Cespedes was great! She was very helpful and really went above and beyond!!Date of experience: August 17, 2023
# Very good!Very good!I have good experience with the support team.Date of experience: July 11, 2023
# Great service and great support!Date of experience: July 18, 2023
# Awesome in all aspects.Date of experience: March 16, 2023
# Shuchi Kumar has made the onboarding…Shuchi Kumar has made the onboarding process smooth and pleasant!Date of experience: June 21, 2023
# Very good company/Platform to get your…Very good company/Platform to get your salaries on time without any hassle.I love it.Date of experience: August 25, 2023
# The company helped with my hiring by a…The company helped with my hiring by a company outside my country. This is wonderful.Date of experience: March 07, 2023
# A team of great professionalsMy experience with Remote has been fabulous! They always assisted me with any concern I had in a timely manner and with great professionalism.I definitely recommend them.Date of experience: May 31, 2023
# I am very satisfied with the support…I am very satisfied with the support provided by this company, and I would like to give a special shout-out to Brian Donal. He is incredibly responsive and takes care of all of my requests and questions in a timely and professional manner. I appreciate his dedication to his work and the company's commitment to providing excellent customer service. I highly recommend this company and appreciate team.Date of experience: March 10, 2023
# The TAT for requests is amazing!Date of experience: June 16, 2023
# Everything went smooth and amazing!Date of experience: August 07, 2023
# Amazing Customer ServiceRemote.com is the best! Very easy to use and navigate! The best part is the customer service! They're super responsive and helpful!Date of experience: August 08, 2023
# It's all good.The support works flawlessly. User-friendly interface.Date of experience: May 09, 2023
# Very clear and great customer service…Very clear and great customer service representatives. Very fluent and clear communication.Date of experience: October 02, 2023
# The team is very responsive and they…The team is very responsive and they made my transition a smooth experience. Big thank you to Akshatha and Diana for all the support!Date of experience: October 11, 2023
# Shetty responded very quickly to all of…Shetty responded very quickly to all of my questions and was friendly and helpful. Thank you!Date of experience: August 03, 2023
# A+ to Remote Onboarding and Help teamsWe have been using Remote as our EoR platform for a while now and their onboarding and help teams are just amazing.  So responsive and timely and things are never a problem.  It's a refreshing change to get such service!  Thanks Franzel and team :-)Date of experience: March 29, 2023
# Kiks is the bestKiks is the best! He helped solve my issue! Thanks again!Date of experience: June 14, 2023

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# Requirement already satisfied: googletrans==4.0.0-rc1 in /usr/local/lib/python3.10/dist-packages (4.0.0rc1)
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.10/dist-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.2.2)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.3.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.10/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.10/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.10/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)

# %% [markdown]
# # **LES COMMENTAIRES DES INTERNAUTES: AVIS POSITIFS ET AVIS NEGATIFS**

# %% [markdown]
# **10 MEILLEURES AVIS POSITIVE TRADUITE EN FRANCAIS**

# %%
from googletrans import Translator

# Initialiser le traducteur
translator = Translator()

# Nombre de commentaires à traduire
nombre_commentaires = 20

# Traduire et afficher les 20 premiers commentaires
for i in range(nombre_commentaires):
    commentaire = sorted_reviews_positive_df['Avis'][i]
    translation = translator.translate(commentaire, src='en', dest='fr')
    print(translation.text)
# Out:
# Emy a vraiment amélioré mon expérience… Emy a vraiment amélioré mon expérience et l'a rendu exceptionnellement positif.Je suis reconnaissante pour sa remarquable capacité à me fournir rapidement les informations nécessaires, ainsi que ses réponses rapides. Date d'expérience: 14 juin 2023
# Shuchi était Amazingshuchi était incroyable!Clear, concis et très réactif. Date d'expérience: 17 août 2023
# Adriana est la meilleure !! Adriana Cespedes était super!Elle a été très serviable et est vraiment allée au-delà !! Date d'expérience: 17 août 2023
# Très bien! Très bien! J'ai une bonne expérience avec l'équipe de soutien. Date d'expérience: 11 juillet 2023
# Grand service et excellent soutien! Date d'expérience: 18 juillet 2023
# Génial dans tous les aspects. Date d'expérience: 16 mars 2023
# Shuchi Kumar a fait l'intégration… Shuchi Kumar a rendu le processus d'intégration lisse et agréable! Date d'expérience: 21 juin 2023
# Très bonne entreprise / plate-forme pour obtenir votre… très bonne entreprise / plate-forme pour obtenir vos salaires à temps sans tracas.J'aime. Date d'expérience: 25 août 2023
# L'entreprise a aidé à mes embauches par un… l'entreprise a aidé à mes embauches par une entreprise à l'extérieur de mon pays.C'est merveilleux. Date d'expérience: 07 mars 2023
# Une équipe de grands professionnels avec éloignement a été fabuleuse!Ils m'ont toujours aidé à toute préoccupation que j'avais en temps opportun et avec un grand professionnalisme. Je les recommande certainement. Date d'expérience: 31 mai 2023
# Je suis très satisfait du soutien… Je suis très satisfait du soutien fourni par cette entreprise, et je voudrais donner un cri spécial à Brian Donal.Il est incroyablement réactif et s'occupe de toutes mes demandes et questions en temps opportun et professionnel.J'apprécie son dévouement à son travail et l'engagement de l'entreprise à fournir un excellent service client.Je recommande fortement cette entreprise et j'apprécie l'équipe. Date d'expérience: 10 mars 2023
# Le tat pour les demandes est incroyable! Date d'expérience: 16 juin 2023
# Tout s'est bien passé et incroyable! Date d'expérience: 07 août 2023
# Le client ServiceMote.com incroyable est le meilleur!Très facile à utiliser et à naviguer!La meilleure partie est le service client!Ils sont super réactifs et utiles! Date d'expérience: 08 août 2023
# Tout va bien. Le support fonctionne parfaitement.Interface conviviale. Date d'expérience: 09 mai 2023
# Service client très clair et excellent… des représentants très clairs et excellents du service client.Communication très courante et claire. Date d'expérience: 02 octobre 2023
# L'équipe est très réactive et ils… l'équipe est très réactive et ils ont fait de ma transition une expérience fluide.Grand merci à Akshatha et Diana pour tout le soutien! Date de l'expérience: 11 octobre 2023
# Shetty a répondu très rapidement à tout… Shetty a répondu très rapidement à toutes mes questions et a été sympathique et serviable.Merci! Date de l'expérience: 03 août 2023
# A + à l'éloignement à l'écart et aide les Teamswe utilisent à distance comme plate-forme EOR depuis un certain temps maintenant et leurs équipes d'intégration et d'aide sont tout simplement incroyables.Si réactif et opportun et les choses ne sont jamais un problème.C'est un changement rafraîchissant pour obtenir un tel service!Merci Franzel et équipe :-) Date d'expérience: 29 mars 2023
# Kiks est le meilleur Kiks est le meilleur!Il a aidé à résoudre mon problème!Merci encore! Date d'expérience: 14 juin 2023

# %% [markdown]
# **10 MEILLEURE AVIS NEGATIVE TRADUITE EN FRANCAIS**

# %%
from googletrans import Translator

# Initialiser le traducteur
translator = Translator()

# Nombre de commentaires à traduire
nombre_commentaires = 20

# Traduire et afficher les 20 premiers commentaires
for i in range(nombre_commentaires):
    commentaire = sorted_reviews_negative_df['Avis'][i]
    translation = translator.translate(commentaire, src='en', dest='fr')
    print(translation.text)
# Out:
# Pire service client du monde. Je demande le formulaire T220 depuis un mois et personne ne veut m'aider.Le service client n'est pas réactif.Aucun moyen de les contacter.Il est de la responsabilité de Remote.com de fournir à leurs employés le formulaire T220 pour le dépôt d'impôts.Ils ne le fourniront même pas.Ils continuent de dire des problèmes techniques depuis plus d'un mois maintenant.Évitez cette entreprise s'il vous plaît !! Date d'expérience: 18 février 2024
# Cette entreprise n'a aucune idée… Cette entreprise n'a aucune idée de ce qu'elle fait!Ils m'ont chassé plusieurs semaines pour un paiement que j'ai fait il y a des semaines.De toute évidence, ils n'ont aucun contrôle sur les paiements et les résultats des résultats, ce qui est tout simplement triste. Date d'expérience: 02 février 2024
# Terrible intérêt et client… Terrible intérêt et support client, puis en plus de tout cela, retardé les paiements de salaire.Cette entreprise n'a aucune idée de comment gérer une entreprise.Séjour à la suite de l'expérience: 30 novembre 2022
# Très mauvais service de mauvais service.Il faut des semaines pour résilier un accord et ils essaient de vous déchirer, vous et vos employés, avec des frais supplémentaires à la fin de l'emploi.Très décevant. Date d'expérience: 19 juillet 2023
# L'incompétence de cette entreprise est au-delà… l'incompétence de cette entreprise est au-delà de la croyance.Non seulement ils ont réussi à bousiller mon dernier glisser, mais leur équipe dite "soutien" régurgite les phrases insensées sans une moindre compréhension sur les questions de paie.C'est une farce.Ils ne peuvent même pas fournir une explication claire sur les taxes déduites, et pour couronner le tout, ils ont l'audace de prétendre qu'ils "rectifieront" leur gâchis un mois plus tard.Travailler pour une entreprise via Remote.com n'a rien de moins qu'un cauchemar avec ces bouffons.Un problème après l'autre! Économisez de la frustration et du manque total de professionnalisme qui définit cette désolé excuse pour une entreprise. Date d'expérience: 31 janvier 2024
# Un service terrible qui ne respecte pas le réglementation du travail est un bon service jusqu'à ce que vous ayez besoin de quoi que ce soit.Leur système de soutien est une catastrophe totale et un laps de temps.Ils sont un proxy entre vous et l'équipe de votre pays.Imaginez avoir une conversation par le biais d'une personne qui ne sait rien du tout de votre législation sur le travail du pays et que chaque question prend une journée à répondre car elle doit confirmer avec une équipe spécialisée.Sachez également que si vous travaillez en Espagne, la télécommande ne se conforme pas aux réglementations du travail espagnol, c'est-à-dire: ils ne suivent pas les heures de travail, ils n'appliquent pas les modifications aux accords de travail annoncés par le gouvernement, ils ne sont pasT se conformer au maximum de l'ABC, ils n'offrent pas les contrôles médicaux chaque année, etc. Le problème est, ils ne savent même pas la plupart de ces choses, vous devez créer des cas de soutien prouvant comment ils doivent faire leur travail RH,ce qui est dommage. J'espère vraiment qu'ils obtiennent une inspection du travail et qu'ils reçoivent la sanction qu'ils méritent. Date d'expérience: 20 décembre 2023
# Italythey à distance ne se soucie pas de leurs clients, ils suivent simplement certaines procédures internes et vous, en tant que client, découvrez ce qui se passe qu'après coup.Très imprévisible et non recommandable.Mon intégration était vague et mon examen médical était prévu près d'un an après avoir déjà commencé à y travailler.La pire partie du service est leur inflexibilité.Mon argent m'a été refusé pendant un mois chaque fois que j'ai reçu une prime ou dans le cas de mon paquet de licenciement.Lorsque j'ai essayé de résoudre le problème, j'ai rencontré des réponses non professionnelles et des captures d'écran mal faites de nos contrats pour me rappeler que tout ce qu'ils font est légal.Je ne doute pas de la légalité, mais je ne pense pas que ce soit une façon d'approcher les gens qui vous paient.À la personne qui essaiera de répondre par «envoyez-nous des commentaires»: j'ai déjà essayé de converser avec vous et vous n'avez rien fait.Veuillez ne pas vous prétendre en soucier.Date d'expérience: 01 juillet 2023
# La pire entreprise à gérer… la pire entreprise à gérer la paie. Ils ne sont jamais en contact ni en comunnication avec votre bord. Ils vous paient ce qu'ils veulent quand ils le veulent.Ils ne se soucient pas de communiquer avec l'autre entreprise et de gérer les minces à droite si vous êtes abke pour fuir cette entreprise, faites-le. Date d'expérience: 04 avril 2023
# Terrible expérience expérimentale.Zéro intégration, aucune information sur les avantages, ils ont mal calculé mon salaire et en plus de cela, ils ne respectent pas les règles locales car elles ne m'ont pas encore fourni mon contrat.0 Recommandé Date d'expérience: 04 mars 2023
# Pas un service digne de confiance, peu fiable et sans aucune idée.Ils nous ont échoué à nous informer des informations importantes pendant le processus d'embauche ("parce que ce n'est pas obligatoire") et en conséquence, nous pouvons faire face à d'énormes responsabilités dans un pays où nous n'avons même pas de présence.Non seulement cela, mais il nous a fallu près de 8 semaines pour enfin parler à une personne via une autre moyenne qui n'est pas un e-mail.Ce ne sont que des courtiers entre vous et les employés et comme tout autre courtier, ils ne sont intéressés par rien d'autre que d'obtenir leurs frais, donc ils se laveront les mains sur n'importe quelle question et vous serez laissé seul. Date d'expérience:26 octobre 2023
# Service client inactif, continuez à transmettre les blâmes à d'autres équipes internes de revuehttps {: //} TRSTP.lt {/} QubnSubit Cela n'a jamais été résolu (à tort mis à jour par réponse à l'agent client distant).Attendant toujours la résolution.Après avoir passé de nombreux appels et courriers, ils ont cessé de répondre.La dernière réponse que j'ai obtenue de leur agent client était le 21 août. Pas une grande expérience du tout. Date d'expérience: 20 septembre 2023
# Remote.com ne se soucie pas des employés, seulement de leurs employeurs, et cela montre.L'expérience entière a été horrible.Tout d'abord, ils ont pris plus de 2 mois pour m'accélérer mon contrat et j'ai dû lancer la demande.S'ils travaillent dans un pays, ils doivent comprendre comment un pays opère concernant l'emploi.Leurs personnes de soutien ont été amicales .. mais généralement inutile, et dans plusieurs cas, j'ai dû supposer l'effort pour m'assurer que les paiements qu'ils n'ont pas réussi à me faire, ce qui impliquait de multiples suivis et escalade au sein de monentreprise.Dans de nombreux cas, j'ai dû assumer ce qui est essentiellement un autre travail à temps partiel pour m'assurer qu'ils remplissent leurs obligations. S'ils bousillent le paiement, ils refusent de faire des seuls pour faire les choses, donc doncVous êtes coincé en attendant 30 jours et espérez qu'ils l'ont corrigé.Quand ils ont foiré ma masse salariale, ils l'ont fait deux mois d'affilée, donc il était 3 mois avant que j'obtienne mon montant de salaire correct. Il n'y a pas un seul contact (ou un ensemble de contacts) pour mon autre entreprise, donc si j'ai besoinaide, je dois suivre leur soutien général et faire face à une personne différente à chaque fois.d'expérience: 14 décembre 2022
# MisUntoutedouedEi a dû reformuler ce dont j'avais besoin deux fois, avant que la distance ne comprenne ma demande.J'ai même dû faire une autre demande pour obtenir une réponse.Lorsque la télécommande a répondu, ils ont fourni des instructions et des vidéos inexactes indiquant où le manuel doit être localisé et il n'était pas là.J'ai dû répondre avec des captures d'écran montrant où ils m'ont dirigé, ce dont j'avais besoin n'était pas dans ce domaine, éloigné puis envoyé un lien auquel je n'avais pas accès et enfin envoyer un PDF de ma demande, avant la fermeture du billet.Je souhaite juste que cela ne fasse pas autant de demandes ou de tentatives pour résoudre mon problème. Date d'expérience: 03 janvier 2023
# Des problèmes de rémunération cohérents ont été avec éloignés depuis 3 mois et chaque mois, il y a eu un problème avec mon salaire et ma paie. Le support est extrêmement lent à répondre très très décevant de l'expérience: 04 décembre 2023
# Un contrat étrange et aucune connaissance locale était nouveau dans le pays dans lequel j'étais embauché, et généralement je m'attendais à ce que mon employeur puisse m'aider avec l'inscription fiscale et de la sécurité sociale que je dois faire.Remote ne savait pas comment cela fonctionnait pour le pays dans lequel je travaillais et m'a donné à plusieurs reprises les mauvaises informations.J'ai été laissé seul pour savoir combien EverTything a fonctionné et faire face au bureau des impôts et lorsque j'ai transmis les informations à éloigner, on m'a dit que j'avais tort encore et encore. En plus, le contrat contenait des choses qui n'avaient pas de sens etétait largement trop restrictif. Ces choses n'étaient résolues qu'avec l'intervention de l'entreprise qui m'embauche par distance, mais elles ont été résolues. Je ne pense pas que je puisse aller à l'éloigneOut ce à quoi j'ai droit. Date d'expérience: 31 août 2022
# Expérience client horrible, expérience client dégoûtante de l'entreprise, même de l'équipe commerciale.Nous avons passé de 1 à 5 personnes sous la promesse d'une remise.À la fin de la journée, il s'agit d'une licence de 25 km par an, donc vraiment pas un service bon marché. Le représentant des ventes est allé en vacances malgré nos demandes répétées pour accélérer, et nous n'avons été attribués à quelqu'un d'autre.Nous avons dû à bord des 4 personnes supplémentaires en raison du démarrage de leur emploi.Devinez quoi?Pas de rabais, rien, pas un soin dans le monde. Équipe de vente vraiment pauvre aussi et interactions médiocres tout au long, obtenant un matériel inutile envoyé à maintes et mainsubstance.Nous avons complètement déplacé tous nos autres employés EOR de la distance.com.date de l'expérience: 14 avril 2023
# J'ai attendu 8 mois pour une réponse sur… J'ai attendu 8 mois pour une réponse sur mon assurance accidentelle. Au début de vous poser une question spécifique à votre emploi, c'est-à-dire pourquoi vous travaillez avec eux, il y a des réponses aléatoires qui n'ont aucun sens du clientAgents de réussite qui n'ont aucune idée de ce dont ils parlent. Date d'expérience: 06 décembre 2022
# Remote.com ne se soucie pas des clients d'Alli a eu une terrible expérience avec Remote.com lorsque je devais renvoyer de l'argent.Malheureusement, la façon dont ils gèrent leurs transferts ont causé beaucoup de problèmes.Ils n'ont pas pu fournir les détails bancaires corrects, et même la communication bancaire interne s'est avérée erronée.Il est difficile de croire que cela pourrait arriver.Pour aggraver les choses, leur service client ne semblait pas se soucier que j'étais sans mon argent pendant plus d'un mois.J'ai essayé de nous contacter, mais il n'y avait pas de numéro de téléphone disponible, et ils ne pouvaient pas me fournir de contacts directs pour m'aider.Après cette expérience, je n'ai plus envie d'utiliser à nouveau la télécommande.com, et je ne le recommanderais certainement à personne. Date d'expérience: 19 avril 2023
# Ils prennent des déductions sans aucune… ils prennent des déductions sans aucune explication, les modifications de mise en page de la rémunération avec un minimum d'informations et lorsque vous devez les contacter à travers un bot conçu par un enfant suivi de jours pour répondre.Déposez la réponse à la coupe et à la collecte sur la façon dont ils veulent aider les ordures .... Date d'expérience: 22 novembre 2023
# Remote.com ne se soucie que des frais… Remote.com ne se soucie que des frais qu'ils sont payés et ne s'intéressent à rien d'autre.L'entreprise pour laquelle j'ai travaillé pour le paiement manqué qui était la faute de l'entreprise et non éloignée, mais mon contrat a été résilié sans avertissement et juste un e-mail avec résiliation à ce moment-là - rien avant ou après.Mon salaire final a été incorrectement taxé, mais ils n'ont aucun devoir de diligence envers moi en tant que «employé» car ils ont simplement refusé de regarder l'erreur et m'ont renvoyé aux RMR pour corriger leur erreur.Je ne peux pas croire à quel point la communication était pauvre pour moi de la distance sans intérêt de corriger quoi que ce soit.Méfiez-vous de ce qui pourrait vous arriver si votre entreprise souhaite utiliser un service à distance.Je ne veux pas mettre mon nom sur cette revue car il y a de nombreux aspects que je ne voudrais pas partager publiquement avec mon Namedate of Experience: 13 septembre 2023

# %% [markdown]
# **RECOMMANDATION**
